# %% [markdown]
# # Introduction

# %% [markdown]
# For this project I want to access my Strava activity data and analyze it using the tools I have been recently learning. I will adress a few questions that a few questions such as the relationships between run distance and kudos, how my running speeds and running distances have been trending, and look at the effect elevation has on these different KPIs.

# %% [markdown]
# # Summary
#
# I begin by taking an overview of general running metrics such as running speed vs distance, and then move over into things I cannot easily gather from looking at my training log such as number of photos vs running speed and likes vs distance. The relationships I found were the ones I expected, but they were rather weak and statistically insignificant.

# %% [markdown]
# # Load the Data

# %% [markdown]
# The first step will be to access my data using the API. This was the bulk of the work for this project I would say. I split it up into two requests, as requesting any more than 200 posts at a time raised an error.

# %%
#Import everything I will need for this 
import requests
import urllib3
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import datetime as dt
from scipy.optimize import curve_fit
import scipy.stats as stats

# %%
#Disable warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

#Urls 
auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

#Things we need for the API to give us the data
payload = {
    'client_id': "75238", 
    'client_secret': '0ad2c3b5d522ef8f4dbbb89d4759efabea4f7ff6',
    'refresh_token': '321e0aa1e8e17d37b2867e4752aa43766474cd3a',

    'grant_type': "refresh_token",
    'f': 'json'
}

print("Requesting Token...\n")
res = requests.post(auth_url, data=payload, verify=False)
access_token = res.json()['access_token']
print("Access Token = {}\n".format(access_token))

header = {'Authorization': 'Bearer ' + access_token}
param = {'per_page': 200, 'page': 1}

my_dataset1 = requests.get(activites_url, headers=header, params=param).json()
print(my_dataset1[0]["name"])
# Out:
# Requesting Token...
#
# Access Token = a1450cf05e2d3bdb9a103a2365175180c3f3b2bf
#
# Lunch Activity

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

payload = {
    'client_id': "75238",
    'client_secret': '0ad2c3b5d522ef8f4dbbb89d4759efabea4f7ff6',
    'refresh_token': '321e0aa1e8e17d37b2867e4752aa43766474cd3a',

    'grant_type': "refresh_token",
    'f': 'json'
}

print("Requesting Token...\n")
res = requests.post(auth_url, data=payload, verify=False)
access_token = res.json()['access_token']
print("Access Token = {}\n".format(access_token))

header = {'Authorization': 'Bearer ' + access_token}

param2 = {'per_page': 200, 'page': 2}
my_dataset2 = requests.get(activites_url, headers=header, params=param2).json()
print(my_dataset2[0]["name"])
# Out:
# Requesting Token...
#
# Access Token = a1450cf05e2d3bdb9a103a2365175180c3f3b2bf
#
# I will now go by Master Michael

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth_url = "https://www.strava.com/oauth/token"
activites_url = "https://www.strava.com/api/v3/athlete/activities"

payload = {
    'client_id': "75238",
    'client_secret': '0ad2c3b5d522ef8f4dbbb89d4759efabea4f7ff6',
    'refresh_token': '321e0aa1e8e17d37b2867e4752aa43766474cd3a',

    'grant_type': "refresh_token",
    'f': 'json'
}

print("Requesting Token...\n")
res = requests.post(auth_url, data=payload, verify=False)
access_token = res.json()['access_token']
print("Access Token = {}\n".format(access_token))

header = {'Authorization': 'Bearer ' + access_token}
param3 = {'per_page': 200, 'page': 3}

my_dataset3 = requests.get(activites_url, headers=header, params=param3).json()
print(my_dataset3[0]["name"])
# Out:
# Requesting Token...
#
# Access Token = a1450cf05e2d3bdb9a103a2365175180c3f3b2bf
#
# Afternoon Run

# %%
raw1 = json_normalize(my_dataset1)
raw2 = json_normalize(my_dataset2)
raw3 = json_normalize(my_dataset3)
#Take a look at what we got
print(raw1.head(2),)
print(raw1.shape)
print(raw1.columns)
# Out:
#    resource_state            name  distance  moving_time  elapsed_time  \
# 0               2  Lunch Activity    9647.2         6622          8389
# 1               2   Afternoon Run   27360.8         7681          9623
#
#    total_elevation_gain       type          id            start_date  \
# 0                 322.0  NordicSki  6500073504  2022-01-09T19:49:41Z
# 1                 351.0        Run  6360899117  2021-12-08T21:50:32Z
#
#        start_date_local  ... workout_type  average_cadence average_watts  \
# 0  2022-01-09T11:49:41Z  ...          NaN              NaN           NaN
# 1  2021-12-08T13:50:32Z  ...          0.0             86.5         240.2
#
#   max_watts weighted_average_watts  kilojoules  device_watts  \
# 0       NaN                    NaN         NaN           NaN
# 1     421.0                  234.0      1845.3          True
#
#    average_heartrate  max_heartrate  suffer_score
# 0                NaN            NaN           NaN
# 1              152.9          191.0         191.0
#
# [2 rows x 60 columns]
# (200, 60)
# Index(['resource_state', 'name', 'distance', 'moving_time', 'elapsed_time',
#        'total_elevation_gain', 'type', 'id', 'start_date', 'start_date_local',
#        'timezone', 'utc_offset', 'location_city', 'location_state',
#        'location_country', 'achievement_count', 'kudos_count', 'comment_count',
#        'athlete_count', 'photo_count', 'trainer', 'commute', 'manual',
#        'private', 'visibility', 'flagged', 'gear_id', 'start_latlng',
#        'end_latlng', 'start_latitude', 'start_longitude', 'average_speed',
#        'max_speed', 'has_heartrate', 'heartrate_opt_out',
#        'display_hide_heartrate_option', 'elev_high', 'elev_low', 'upload_id',
#        'upload_id_str', 'external_id', 'from_accepted_tag', 'pr_count',
#        'total_photo_count', 'has_kudoed', 'athlete.id',
#        'athlete.resource_state', 'map.id', 'map.summary_polyline',
#        'map.resource_state', 'workout_type', 'average_cadence',
#        'average_watts', 'max_watts', 'weighted_average_watts', 'kilojoules',
#        'device_watts', 'average_heartrate', 'max_heartrate', 'suffer_score'],
#       dtype='object')

# %% [markdown]
# Now that we have the data in three differenct dataframes, I will use Pandas to anlayze them futher. The first step for this will be to make them into one larger dataframe. After that I will make them into one dataframe, and drop all columns that I'm not currently interested in. We also will alter the start time column to make it more usable.

# %%
# Concatenate the dataframes and re-index
raw = pd.concat([raw1,raw2, raw3], ignore_index = True)

#These are the columns that I think will be useful
cols = ['name' , 'distance', 'moving_time', 'elapsed_time', 'total_elevation_gain', 'type', 'start_date_local', 'start_latlng', 'kudos_count', 'comment_count', 'athlete_count', 'total_photo_count', 'elev_high']

#Remove other columns and then non-runs
raw = raw[cols]
run = raw[raw['type'] == 'Run']

#Change date column to pandas datetime then make two columns with data and hour seperate
run['start_date_local'] = pd.to_datetime(run['start_date_local'])
run['start_hour'] = run['start_date_local'].dt.hour
run['start_date_local'] = run['start_date_local'].dt.date

#Create a new column for the average moving speed of each run
run['avg_speed'] = (run['distance']/1000)/(run['moving_time']/3600)
run.head()
# Out:
#             name  distance  moving_time  elapsed_time  total_elevation_gain  \
# 1  Afternoon Run   27360.8         7681          9623                 351.0
# 2  Afternoon Run    8594.6         2922          3031                  95.0
# 3    Morning Run    3262.9          983          1019                  35.0
# 4  Afternoon Run   10203.9         4122          4713                 420.0
# 5  Afternoon Run   10761.8         3513          4199                  97.0
#
#   type start_date_local                               start_latlng  \
# 1  Run       2021-12-08   [39.52228160575032, -119.79902666062117]
# 2  Run       2021-12-07    [39.4708876311779, -119.80312775820494]
# 3  Run       2021-12-07  [39.522215221077204, -119.79942287318408]
# 4  Run       2021-12-05  [39.371368708088994, -119.70708447508514]
# 5  Run       2021-12-04   [39.24743011593819, -119.97017548419535]
#
#    kudos_count  comment_count  athlete_count  total_photo_count  elev_high  \
# 1            1              0              1                  0     1512.0
# 2            2              0              2                  0     1428.0
# 3            1              0              1                  0     1387.0
# 4            1              0              2                  0     1939.0
# 5            1              0              2                  2     1938.0
#
#    start_hour  avg_speed
# 1          13  12.823705
# 2          17  10.588830
# 3           9  11.949583
# 4          15   8.911703
# 5          15  11.028318

# %% [markdown]
# # Missing Data
#
# We will see if there is any missing data and come up with a technique for dealing with it if need be.

# %%
#See which columns I will need to deal with
run.isnull().sum()
# Out:
# name                     0
# distance                 0
# moving_time              0
# elapsed_time             0
# total_elevation_gain     0
# type                     0
# start_date_local         0
# start_latlng             0
# kudos_count              0
# comment_count            0
# athlete_count            0
# total_photo_count        0
# elev_high               93
# start_hour               0
# avg_speed                0
# dtype: int64

# %% [markdown]
# The 93 null values are from when I had to run in the gym due to wildfire smoke, or when I was just running without a watch, so I'm going to fill them with the elevation of Reno. I will also attempt

# %%
#Fill all the zeros with elevation of Reno in meters
run['elev_high'] = run['elev_high'].fillna(1373)
run.isnull().sum()
# Out:
# name                    0
# distance                0
# moving_time             0
# elapsed_time            0
# total_elevation_gain    0
# type                    0
# start_date_local        0
# start_latlng            0
# kudos_count             0
# comment_count           0
# athlete_count           0
# total_photo_count       0
# elev_high               0
# start_hour              0
# avg_speed               0
# dtype: int64

# %% [markdown]
# # Intro Exploratory Data Anlysis
#
# Now that the data is cleaned up I will take a look at the correlation matrix to see if the relationship between any of the columns is surprising and worth investigating.

# %%
#Set seaborn palette to colorblind
sns.set_palette('colorblind')

#Look at the correlation matrix 
corrMat = run.corr()
sns.heatmap(corrMat, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see there isn't a whole lot that is surprisingly correlated. Longer distances tend to take more time, more vert tends to make me slower... etc. What I do find interesting are the relationships between both number of photos and number of kudos (Strava's version of likes) and other variables.
#
# But before going on to that we should take a look at more the more standard running metrics and their relationships.

# %%
#Regression pair plot of the standard metrics

sns.pairplot(run[['distance', 'avg_speed', 'total_elevation_gain', 'moving_time']], kind = 'scatter')

# %% [markdown]
# Again we don't see aything surprising here besides the visualization of how weak the correlation between distance and average speed is for me (-.2 from the correlation matrix). I suspect the reasoning for that is that my runs do not get longer or shorter throughout my training seasons any more, so I have a lot of similar distance runs where I will be running faster later in the season.

# %%
#Look at date vs avg speed (note we need to index it backwards to get it in increasing time order)

sns.relplot(kind = 'scatter', x = run.index[::-1], y = 'avg_speed', data = run).set(title = 'Average Speed over Time', ylabel = 'Average Speed (kph)', xlabel = 'Run # since May 2020')

# %% [markdown]
# We see a slight negative relationship between the run index and the average speed. This indicates that I haven't really been running slower by all that much over time. It does seem that I have not been running as many hard runs for the past 200 runs which makes sense as I was training for an ultramarathon and simeultaneously got COVID (this may account for a large part of the negative relationship). To see about this I'll do the same thing with time and distance.

# %% [markdown]
# It would be interesting to see if start time affects my speed at all...

# %%
#Plot time vs avg speed
sns.regplot( x = 'start_hour', y = 'avg_speed', data = run, x_jitter=0.25).set(title = 'Run start time vs Average Speed', xlabel = 'Starting Hour (24hr)', ylabel = 'Average Speed (kph)')
# Out:
# [Text(0.5, 1.0, 'Run start time vs Average Speed'),
#  Text(0.5, 0, 'Starting Hour (24hr)'),
#  Text(0, 0.5, 'Average Speed (kph)')]

# %% [markdown]
# It appears that the later in the day I start I am slightly more likely to run faster. This makes sense as I tend to start longer runs earlier and I run slower during those. Also it tends to be hard to wake up and run fast.

# %%
#Plot index (flipped) vs distance
sns.relplot(kind = 'scatter', x = run.index[::-1], y = 'distance', data = run, alpha = 0.65, color = 'g').set(title = 'Distance over Time', xlabel = 'Run # since May 2020', ylabel = 'Distance (m)')

# %% [markdown]
# Contrary to my assumption I have not been running discernably longer since May 2020.

# %% [markdown]
# # Less Standard Metrics
#
# ### Photos vs Speed
#
# Now to move on, let's do some testing on the relationship between number of photographs uploaded and average speed (moving time, so not including time to take the pictures).

# %%
#Boxplot and strip plot of photos vs speed

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(16,8))
fig.suptitle('Number of Photos vs Avg Speed')
sns.boxplot(ax=ax[0], y='avg_speed', x='total_photo_count', data=run).set(xlabel='# of Photos', ylabel='Average Speed (kph)')
sns.stripplot(ax=ax[1], data=run, x='total_photo_count', y='avg_speed').set(xlabel='# of Photos', ylabel='Average Speed (kph)')
# Out:
# [Text(0.5, 0, '# of Photos'), Text(0, 0.5, 'Average Speed (kph)')]

# %% [markdown]
# We see a negative relationship between speed and number of photos from the boxplot. This is mitigated by the lack of runs with a large amount of photos as seen in the strip plot. In light of this, let's pivot to a test between photos and no photos, as that will give us the most accurate results. If we are interested in the difference between average speed between the two groups for only the last 600 runs we could just look at the population data and see if there is a difference, but if we are interested in applying the results to all of my runs we would have a problem as my data is not a random sample which is a necessary assumption for applying a t-test. Instead, I will just take a random sample of my data and see if the test agrees with the population data.

# %%
#Make two new series that split the original dataframe between runs that have photos attached and those that don't
photo_0 = run['avg_speed'][run['total_photo_count'] == 0]
photo_1 = run['avg_speed'][run['total_photo_count'] >= 1]

sample_0 = photo_0.sample(n = 30, random_state = 42)
sample_1 = photo_1.sample(n = 30, random_state = 42)

#Look at the summary statistics
print(photo_0.describe())
print(photo_1.describe())
        
#t-test the two groups     
stats.ttest_ind(sample_0, sample_1)
# Out:
# count    488.000000
# mean      11.177209
# std        2.174097
# min        4.360571
# 25%        9.985519
# 50%       11.455267
# 75%       12.586650
# max       18.360312
# Name: avg_speed, dtype: float64
# count    105.000000
# mean       9.929625
# std        2.891333
# min        2.253080
# 25%        7.689108
# 50%        9.853393
# 75%       12.070125
# max       16.210476
# Name: avg_speed, dtype: float64
# Ttest_indResult(statistic=3.204190208809672, pvalue=0.002202202928809825)

# %% [markdown]
# So among my last 600 runs we do see a difference in mean average speed of about 1.3 km/hr. After taking a sample of 30 runs from each group I applied the t-test to see if the test returns the same result, and saw that the test estimates that there is a difference in the true mean average speed between runs with no photos and runs with them (at a 99% confidence level).
#
# Note that this is a 2-sided test as Jupyter Notebook is running off an older version of SciPy where there is no "alternative" keyword argument. If there were I would have done a 1-sided test, but the result would have been the same.
#
# But either way we reject the null hypothesis that there is no difference in the true mean average speed between runs with no photos and runs with photos.
#
# We probably have some confounding variables in here though like distance or location, as I am probably taking photos in locations that are pretty and people might like that more, or I am running further when I take photos and people like that. We first will deal with the distance question. To do this I will split the dataframe into four new ones which are grouped by distance run.

# %% [markdown]
# ### Controlling for Distance

# %%
# I want to group my runs by distance, so I will split my runs into four groups 
groups = [10000, 15000, 25000, 100000]
#Initialize dataframes
run_10k = pd.DataFrame()
run_15k = pd.DataFrame()
run_25k = pd.DataFrame()
run_100k = pd.DataFrame()
distances = [run_10k, run_15k, run_25k, run_100k] 

#Populate the dataframes with the appropriate distances
for i in range(4):
    if i == 0:
        distances[i] = run[run['distance'] <= groups[i]]
    else:
        distances[i] = run[(run['distance'] <= groups[i]) & (run['distance'] > groups[i-1])]

distances[0].head()
# Out:
#              name  distance  moving_time  elapsed_time  total_elevation_gain  \
# 2   Afternoon Run    8594.6         2922          3031                  95.0
# 3     Morning Run    3262.9          983          1019                  35.0
# 8       Lunch Run    3219.1          956          1070                  35.0
# 10  Afternoon Run    8740.7         2975          2975                  86.0
# 12    Evening Run    9100.1         3095          3241                  36.0
#
#    type start_date_local                               start_latlng  \
# 2   Run       2021-12-07    [39.4708876311779, -119.80312775820494]
# 3   Run       2021-12-07  [39.522215221077204, -119.79942287318408]
# 8   Run       2021-12-02   [39.52225612476468, -119.79919798672199]
# 10  Run       2021-11-30  [39.470813032239676, -119.80358599685133]
# 12  Run       2021-11-28   [39.52223760075867, -119.79943184182048]
#
#     kudos_count  comment_count  athlete_count  total_photo_count  elev_high  \
# 2             2              0              2                  0     1428.0
# 3             1              0              1                  0     1387.0
# 8             1              0              1                  0     1391.0
# 10            1              0              5                  0     1424.0
# 12            1              0              2                  0     1373.0
#
#     start_hour  avg_speed
# 2           17  10.588830
# 3            9  11.949583
# 8           11  12.122134
# 10          17  10.576982
# 12          18  10.584931

# %% [markdown]
# Now that that is done lets plot photo count vs average speed.

# %%
#Define titles for plots
titles = ['dist<10k', '10k< dist <15k', '15k< dist <25k' , '25k< dist <100k'] 

#Set up 4 side-by-side plots
fig, ax = plt.subplots(1,4, sharex = True, sharey = True, figsize = (12,5))

#Populate each plot using a for loop pulling data from the distances list in cell above
for i in range(4):
    sns.barplot(ax = ax[i], x = distances[i]['total_photo_count'], y = distances[i]['avg_speed'], data = distances[i])
    ax[i].set_title(titles[i])
    ax[i].set_xlabel('# of photos')
    ax[i].set_ylabel('Avg Speed (kph)')

# %% [markdown]
# We can see that for really short and really long runs there isn't a discernable relationship beween photos and speed. For the middle distance groups there does seem to be a negative relationship betweent the two. I think this is because for those distances I run on a mixture of trails and roads where I rarely take photos on roads and take plentiful photos on trails which tend to be slower runs. For longer runs I run almost soley on trails which are slower and the opposite for shorter runs, so we won't see a large difference in speed of those. I do find it interesting that I move at about the same speed from 0 up to 25k if I am not taking photos.

# %% [markdown]
# ### Photos vs Kudos
#
# Now, I want to do the same thing, but with kudos and photos accounting for distance.

# %%
# Initializing 4 side-by-side plots
fig, ax = plt.subplots(1,4, sharex = True, sharey = True, figsize = (12,5))

#For loop to populate the plots with photos and kudos 
for i in range(4):
    sns.barplot(ax = ax[i], x = distances[i]['total_photo_count'], y = distances[i]['kudos_count'], data = distances[i], ci = False)
    ax[i].set_title(titles[i])
    ax[i].set_xlabel('# of photos')
    ax[i].set_ylabel('# of kudos')

# %% [markdown]
# It seems like if I am running up to 25k and want the most kudos that I should include a few photos. For longer runs it looks like it is hit or miss.

# %% [markdown]
# ### Distance vs Kudos
# Looking back at the correlation matrix, we saw that distance vs kudos had a moderatly strong correlation, so lets plot a scatter plot to visualize it.

# %%
#Regression plot of distance vs kudos 
sns.regplot(y = 'kudos_count', x = 'distance', data = run, y_jitter=0.25).set(title = 'Distance vs Kudos', xlabel = 'Distance (m)', ylabel = '# of Kudos')
# Out:
# [Text(0.5, 1.0, 'Distance vs Kudos'),
#  Text(0.5, 0, 'Distance (m)'),
#  Text(0, 0.5, '# of Kudos')]

# %% [markdown]
# We do see a relationship between kudos and distance, but with diminishing returns as the number of followers doesn't increase as I run farther.

# %% [markdown]
# The last thing I would like to look at is what would happen if I got rid of the longer distances in the above plot as they seem to be pulling the regression line down by quite a bit.

# %%
#Subset dataframe into runs shorter than 23k
short = run[run['distance'] < 23000]
#Plot
sns.regplot(data = short, x = 'distance', y = 'kudos_count', y_jitter=0.25)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='kudos_count'>

# %% [markdown]
# ### Correlation Without Longer Runs

# %%
corrMat1 = short.corr()
sns.heatmap(corrMat1, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It appears that after removing the longer runs, almost everything has a lower correlation. You notice a significant decrease in the correlation of elapsed time and distance which is surprising as I would have guessed that the opposite would have been true considering I stop to eat for varying amounts of times while running long, whereas when I run under 15 miles or so I don't tend to stop at all.

# %% [markdown]
# # Conclusions
#
# The key take-away here is that my running and strava performace (at least in terms of likes) are not as predictible as I would have thought. The relationships between running distance and kudos was positive as I expected it to be, but was not as strong as I would have thought. The same goes for photos vs average speed, and photos vs kudos.
#
# In the future I would like to pracitce some machine learning techniques on my running data. It would be well suited for regression I would say, but I would like to have more data to work with before doing that.
